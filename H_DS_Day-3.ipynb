# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### LINE PLOT

# %%
x=np.array([3,11,16,23,17,34,48,55,56,67])

# %%
y=np.array([13,23,34,23,47,61,69,78,84,89])

# %%
plt.plot(x,y)

# %%
plt.title('My First Plot')
plt.xlabel('first Value')
plt.ylabel('Second Value')
plt.grid()
plt.xlim(0,80)
plt.ylim(0,100)
plt.xticks(range(0,81,10))
plt.yticks(range(0,101,10))
plt.plot(x,y)

# %%
z=np.array([87,77,75,71,65,51,34,21,19,2])

# %%
plt.title('My First Plot')
plt.xlabel('first Value')
plt.ylabel('Second Value')
plt.grid()
plt.xlim(0,80)
plt.ylim(0,100)
plt.xticks(range(0,81,10))
plt.yticks(range(0,101,10))
plt.plot(x,z)

# %%
plt.title('My First Plot')
plt.xlabel('first Value')
plt.ylabel('Second Value')
plt.grid()
plt.xlim(0,80)
plt.ylim(0,100)
plt.xticks(range(0,81,10))
plt.yticks(range(0,101,10))
#marker:  o  >  <  v  ^  D  *
plt.plot(x,y,marker='o',color='blue',ls=':',lw=2, mfc='green')

# %%
plt.title('My First Plot')
plt.xlabel('first Value')
plt.ylabel('Second Value')
plt.grid()
plt.plot(x,y,label='2022',color='blue')
plt.plot(x,z,label='2023',color='green')
plt.legend()

# %%
plt.subplot(2,1,1)
plt.plot(x,y)
plt.subplot(2,1,2)
plt.plot(x,z)

# %%
plt.subplot(1,2,1)
plt.plot(x,y)
plt.subplot(1,2,2)
plt.plot(x,z)

# %%
plt.figure(figsize=(16,9))
plt.title('My First Plot')
plt.xlabel('first Value')
plt.ylabel('Second Value')
plt.grid()
plt.plot(x,y,label='2022',color='blue')
plt.plot(x,z,label='2023',color='green')
plt.legend()

# %% [markdown]
# ### SCATTER PLOT

# %%
plt.title('My First Plot')
plt.xlabel('first Value')
plt.ylabel('Second Value')
plt.grid()
plt.scatter(x,y)

# %%
java=np.array([67,45,62,89,41,59,78,46,81,79,47,65])
python=np.array([62,42,69,91,46,60,74,52,85,82,45,68])
cols=[1,2,1,3,2,1,3,2,3,3,2,1]

# %%
plt.title('My First Plot')
plt.xlabel('Java Marks')
plt.ylabel('Python Marks')
plt.grid()
plt.scatter(java,python, c=cols)

# %% [markdown]
# ### BAR PLOT

# %%
percentage=[89.56,45.36,76.45,65.90,11.34,71.94]
subjects=['Python','PHP','Data Structure','JAVA','C','OOPS']

# %%
plt.title('Result analysis')
plt.xlabel('Subjects')
plt.ylabel('% of Passing')
plt.bar(subjects,percentage,color='#afcd0e')
# Out:
# <BarContainer object of 6 artists>

# %%
plt.title('Result analysis')
plt.xlabel('Subjects')
plt.ylabel('% of Passing')
plt.barh(subjects,percentage,color='#afcd0e')
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ### PIE CHART

# %%
enrollment=[167,67,89,106,48,99]
courses=['Python','PHP','Data Structure','JAVA','C','OOPS']

# %%
plt.figure(figsize=(7,7))
plt.pie(enrollment,labels=courses,autopct='%2.2f%%');

# %% [markdown]
# ### PANDAS

# %%
import pandas as pd

# %%
df=pd.read_csv('imcc.csv')

# %%
plt.figure(figsize=(16,9))
plt.barh(df['name'],df['sgpa'])
# Out:
# <BarContainer object of 51 artists>

# %% [markdown]
# ## UNIVARIATE ANALYSIS

# %% [markdown]
# ### HISTOGRAM

# %%
marks=np.array([56,67,72,93,75,45,26,58,65,61,68,47])

# %%
plt.xlabel('Range of Marks')
plt.ylabel('counts')
plt.xticks(range(0,101,10))
plt.hist(marks,color='#afcd0e',bins=range(0,101,10));

# %% [markdown]
# ###  BOX PLOT

# %%
plt.boxplot(marks);

# %%
plt.boxplot(df['sgpa']);

# %% [markdown]
# ### LINEAR REGRESSION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Salary_Data.csv')

# %%
df.shape
# Out:
# (30, 2)

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
plt.scatter(df['YearsExperience'],df['Salary']);

# %%
a=np.arange(1,10,0.25)

# %%
a
# Out:
# array([1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 ,
#        3.75, 4.  , 4.25, 4.5 , 4.75, 5.  , 5.25, 5.5 , 5.75, 6.  , 6.25,
#        6.5 , 6.75, 7.  , 7.25, 7.5 , 7.75, 8.  , 8.25, 8.5 , 8.75, 9.  ,
#        9.25, 9.5 , 9.75])

# %%
b=a*1.56+32.67

# %%
b
# Out:
# array([34.23, 34.62, 35.01, 35.4 , 35.79, 36.18, 36.57, 36.96, 37.35,
#        37.74, 38.13, 38.52, 38.91, 39.3 , 39.69, 40.08, 40.47, 40.86,
#        41.25, 41.64, 42.03, 42.42, 42.81, 43.2 , 43.59, 43.98, 44.37,
#        44.76, 45.15, 45.54, 45.93, 46.32, 46.71, 47.1 , 47.49, 47.88])

# %%
plt.plot(a,b)  #y is always the OUTPUT VARIABLE

# %%
x=df['YearsExperience'].values
y=df['Salary']

# %%
x
# Out:
# array([ 1.1,  1.3,  1.5,  2. ,  2.2,  2.9,  3. ,  3.2,  3.2,  3.7,  3.9,
#         4. ,  4. ,  4.1,  4.5,  4.9,  5.1,  5.3,  5.9,  6. ,  6.8,  7.1,
#         7.9,  8.2,  8.7,  9. ,  9.5,  9.6, 10.3, 10.5])

# %%
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
plt.plot(x,y);

# %%
x=x.reshape(30,1);
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %% [markdown]
# ### IMPORT THE CLASS

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### create the object of linear regression

# %%
regressor=LinearRegression()

# %% [markdown]
# #### Train the Algorithm with data

# %%
regressor.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# #### Predict on unseen data

# %%
regressor.predict([[15]])
# Out:
# array([167541.63502049])

# %%
regressor.predict([[1]])
# Out:
# array([35242.16252012])

# %%
regressor.predict([[10]])
# Out:
# array([120291.82341322])

# %%
regressor.predict([[5]])
# Out:
# array([73042.01180594])

# %%
regressor.predict([[0]])
# Out:
# array([25792.20019867])
